# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
import joblib

# %%
df = pd.read_csv("cases.csv")

X = df["case"]
y = df["section"]

vectorizer = TfidfVectorizer()
X_vec = vectorizer.fit_transform(X)

model = SGDClassifier(loss="log_loss", max_iter=1, warm_start=True, random_state=42)

epochs = 50
for epoch in range(epochs):
    model.fit(X_vec, y)
    y_pred = model.predict(X_vec)
    acc = accuracy_score(y, y_pred)
    print(f"Epoch {epoch+1}/{epochs} - Training Accuracy: {acc:.4f}")

# Save model and vectorizer
joblib.dump(model, "model.pkl")
joblib.dump(vectorizer, "vectorizer.pkl")

print("Model trained with epochs and saved successfully!")
# Out:
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# Epoch 1/50 - Training Accuracy: 1.0000
# Epoch 2/50 - Training Accuracy: 1.0000
# Epoch 3/50 - Training Accuracy: 1.0000
# Epoch 4/50 - Training Accuracy: 1.0000
# Epoch 5/50 - Training Accuracy: 1.0000
# Epoch 6/50 - Training Accuracy: 1.0000
# Epoch 7/50 - Training Accuracy: 1.0000
# Epoch 8/50 - Training Accuracy: 1.0000
# Epoch 9/50 - Training Accuracy: 1.0000
# Epoch 10/50 - Training Accuracy: 1.0000
# Epoch 11/50 - Training Accuracy: 1.0000
# Epoch 12/50 - Training Accuracy: 1.0000
# Epoch 13/50 - Training Accuracy: 1.0000
# Epoch 14/50 - Training Accuracy: 1.0000
# Epoch 15/50 - Training Accuracy: 1.0000
# Epoch 16/50 - Training Accuracy: 1.0000
# Epoch 17/50 - Training Accuracy: 1.0000
# Epoch 18/50 - Training Accuracy: 1.0000
# Epoch 19/50 - Training Accuracy: 1.0000
# Epoch 20/50 - Training Accuracy: 1.0000
# Epoch 21/50 - Training Accuracy: 1.0000
# Epoch 22/50 - Training Accuracy: 1.0000
# Epoch 23/50 - Training Accuracy: 1.0000
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# Epoch 24/50 - Training Accuracy: 1.0000
# Epoch 25/50 - Training Accuracy: 1.0000
# Epoch 26/50 - Training Accuracy: 1.0000
# Epoch 27/50 - Training Accuracy: 1.0000
# Epoch 28/50 - Training Accuracy: 1.0000
# Epoch 29/50 - Training Accuracy: 1.0000
# Epoch 30/50 - Training Accuracy: 1.0000
# Epoch 31/50 - Training Accuracy: 1.0000
# Epoch 32/50 - Training Accuracy: 1.0000
# Epoch 33/50 - Training Accuracy: 1.0000
# Epoch 34/50 - Training Accuracy: 1.0000
# Epoch 35/50 - Training Accuracy: 1.0000
# Epoch 36/50 - Training Accuracy: 1.0000
# Epoch 37/50 - Training Accuracy: 1.0000
# Epoch 38/50 - Training Accuracy: 1.0000
# Epoch 39/50 - Training Accuracy: 1.0000
# Epoch 40/50 - Training Accuracy: 1.0000
# Epoch 41/50 - Training Accuracy: 1.0000
# Epoch 42/50 - Training Accuracy: 1.0000
# Epoch 43/50 - Training Accuracy: 1.0000
# Epoch 44/50 - Training Accuracy: 1.0000
# Epoch 45/50 - Training Accuracy: 1.0000
# Epoch 46/50 - Training Accuracy: 1.0000
# Epoch 47/50 - Training Accuracy: 1.0000
# Epoch 48/50 - Training Accuracy: 1.0000
# Epoch 49/50 - Training Accuracy: 1.0000
# Epoch 50/50 - Training Accuracy: 1.0000
# Model trained with epochs and saved successfully!
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:726: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Deepan\AIML\PycharmProjects\AL Lawyer Assistant\venv\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
